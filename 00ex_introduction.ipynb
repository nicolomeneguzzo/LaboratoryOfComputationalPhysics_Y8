# %% [markdown]
# 1. The MickeyMouse problem
#
# a) Write a program that prints the numbers from 1 to 100. But for multiples of 3 print `Mickey` instead of the corresponding number and for the multiples of 5 print `Mouse`. For numbers which are multiples of both three and five print `MickeyMouse`
#
# b) Put the result in a tuple and substitute `Mickey` with `Donald` and `Mouse` with `Duck`

# %%
from operator import contains

i=1
t=[]

while i <= 100:
    if i%3==0 and i%5==0:
        print('MickeyMouse')
        t.append('MickeyMouse')
    elif i%3==0:
        print('Mickey')
        t.append('Donald')
    elif i%5==0:
        print('Mouse')
        t.append('Duck')
    else:
        print(i)
        t.append(i)
    i +=1
tupla = tuple(t)    
print(type(tupla), tupla)
# Out:
# 1
# 2
# Mickey
# 4
# Mouse
# Mickey
# 7
# 8
# Mickey
# Mouse
# 11
# Mickey
# 13
# 14
# MickeyMouse
# 16
# 17
# Mickey
# 19
# Mouse
# Mickey
# 22
# 23
# Mickey
# Mouse
# 26
# Mickey
# 28
# 29
# MickeyMouse
# 31
# 32
# Mickey
# 34
# Mouse
# Mickey
# 37
# 38
# Mickey
# Mouse
# 41
# Mickey
# 43
# 44
# MickeyMouse
# 46
# 47
# Mickey
# 49
# Mouse
# Mickey
# 52
# 53
# Mickey
# Mouse
# 56
# Mickey
# 58
# 59
# MickeyMouse
# 61
# 62
# Mickey
# 64
# Mouse
# Mickey
# 67
# 68
# Mickey
# Mouse
# 71
# Mickey
# 73
# 74
# MickeyMouse
# 76
# 77
# Mickey
# 79
# Mouse
# Mickey
# 82
# 83
# Mickey
# Mouse
# 86
# Mickey
# 88
# 89
# MickeyMouse
# 91
# 92
# Mickey
# 94
# Mouse
# Mickey
# 97
# 98
# Mickey
# Mouse
# ...

# %% [markdown]
# 2\. The swap function
#
# Write a function that swap the values of two input variables x and y (whatever the type). Try to do that also without a temporary variable

# %%
#def func(x=input('x='), y=input('y=')):
 #   t=x
 #  x=y
 #   y=t
 #   print('x=', x, 'y=', y)


def swap(x=input('x='), y=input('y=')):
    return y, x
x, y=swap()
print(x,y)
# Out:
# x=5
# y=13
# 13 5

# %% [markdown]
# 3\. Computing the distance
#
# Write a function that calculates and returns the euclidean distance between two points *u* and *v*, where *u* and *v* are both 2-tuples *(x,y)*. For example, if *u=(3,0)* and *v=(0,4)*, the function should return 5

# %%
u=(3,0)
v=(0,4)
import math as np

def dist(a, b):
    return np.sqrt((a[0]-b[0])**2+(a[1]-b[1])**2)
d=dist(u, v)
print(d)
# Out:
# 5.0

# %% [markdown]
# 4\. Counting letters
#
# Write a program to calculate the number of times each character occurs in a given string *s*. Ignore differneces in capitalization

# %%
s="Write a program that prints the numbers from 1 to 100. \
But for multiples of three print Mickey instead of the number and for the multiples of five print Mouse. \
For numbers which are multiples of both three and five print MickeyMouse"

def count(s):
    s=s.lower()
    counts={}
    
    for c in s:
        if c in counts:
            counts[c] += 1
        else:
            counts[c] = 1
    return counts
count(s)
# Out:
# {'w': 2,
#  'r': 17,
#  'i': 14,
#  't': 19,
#  'e': 22,
#  ' ': 41,
#  'a': 7,
#  'p': 8,
#  'o': 13,
#  'g': 1,
#  'm': 12,
#  'h': 9,
#  'n': 10,
#  's': 9,
#  'u': 9,
#  'b': 5,
#  'f': 10,
#  '1': 2,
#  '0': 2,
#  '.': 2,
#  'l': 6,
#  'c': 3,
#  'k': 2,
#  'y': 2,
#  'd': 3,
#  'v': 2}

# %%
s="Write a program that prints the numbers from 1 to 100. \
But for multiples of three print Mickey instead of the number and for the multiples of five print Mouse. \
For numbers which are multiples of both three and five print MickeyMouse"

def cont(s):
    s=s.lower()
    counts={}
    print(s)
    
    for c in s:
        if c.isalnum:
            counts[c]=counts.get(c, 0)+1
    return counts
cont(s)
# Out:
# write a program that prints the numbers from 1 to 100. but for multiples of three print mickey instead of the number and for the multiples of five print mouse. for numbers which are multiples of both three and five print mickeymouse
# {'w': 2,
#  'r': 17,
#  'i': 14,
#  't': 19,
#  'e': 22,
#  ' ': 41,
#  'a': 7,
#  'p': 8,
#  'o': 13,
#  'g': 1,
#  'm': 12,
#  'h': 9,
#  'n': 10,
#  's': 9,
#  'u': 9,
#  'b': 5,
#  'f': 10,
#  '1': 2,
#  '0': 2,
#  '.': 2,
#  'l': 6,
#  'c': 3,
#  'k': 2,
#  'y': 2,
#  'd': 3,
#  'v': 2}

# %% [markdown]
# 5\. Isolating the unique
#
# Write a function that determines and count the unique numbers in the list *l*

# %%
d = {}
print(dir(d))
help(d)
# Out:
# ['__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__ior__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']
# Help on dict object:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
#  |      for k, v in iterable:
#  |          d[k] = v
#  |  dict(**kwargs) -> new dictionary initialized with the name=value pairs
# ...

# %%
l = [36, 45, 58, 3, 74, 96, 64, 45, 31, 10, 24, 19, 33, 86, 99, 18, 63, 70, 85,
 85, 63, 47, 56, 42, 70, 84, 88, 55, 20, 54, 8, 56, 51, 79, 81, 57, 37, 91,
 1, 84, 84, 36, 66, 9, 89, 50, 42, 91, 50, 95, 90, 98, 39, 16, 82, 31, 92, 41,
 45, 30, 66, 70, 34, 85, 94, 5, 3, 36, 72, 91, 84, 34, 87, 75, 53, 51, 20, 89, 51, 20]

def unique(l):
    counts={}
    
    for i in l:
        if i in counts:
            counts[i] += 1
        else:
            counts[i] = 1
    uniques = [k for k, v in counts.items() if v == 1] #counts.items() mi restituisce una lista di coppie chiave e valore
    return uniques, len(uniques)
   
print(unique(l))
# Out:
# dict_items([(36, 3), (45, 3), (58, 1), (3, 2), (74, 1), (96, 1), (64, 1), (31, 2), (10, 1), (24, 1), (19, 1), (33, 1), (86, 1), (99, 1), (18, 1), (63, 2), (70, 3), (85, 3), (47, 1), (56, 2), (42, 2), (84, 4), (88, 1), (55, 1), (20, 3), (54, 1), (8, 1), (51, 3), (79, 1), (81, 1), (57, 1), (37, 1), (91, 3), (1, 1), (66, 2), (9, 1), (89, 2), (50, 2), (95, 1), (90, 1), (98, 1), (39, 1), (16, 1), (82, 1), (92, 1), (41, 1), (30, 1), (34, 2), (94, 1), (5, 1), (72, 1), (87, 1), (75, 1), (53, 1)])

# %%
l = [36, 45, 58, 3, 74, 96, 64, 45, 31, 10, 24, 19, 33, 86, 99, 18, 63, 70, 85,
 85, 63, 47, 56, 42, 70, 84, 88, 55, 20, 54, 8, 56, 51, 79, 81, 57, 37, 91,
 1, 84, 84, 36, 66, 9, 89, 50, 42, 91, 50, 95, 90, 98, 39, 16, 82, 31, 92, 41,
 45, 30, 66, 70, 34, 85, 94, 5, 3, 36, 72, 91, 84, 34, 87, 75, 53, 51, 20, 89, 51, 20]



def count(l):
    conta={}
    for c in l:
        if isinstance(c, int):
            conta[c]=conta.get(c, 0)+1

    unici = [x for x in conta if conta[x]==1]
    print("Numeri unici:", *unici)
    print('totale=', len(unici))
    #return *unici, len(unici)
count(l)
# Out:
# Numeri unici: 58 74 96 64 10 24 19 33 86 99 18 47 88 55 54 8 79 81 57 37 1 9 95 90 98 39 16 82 92 41 30 94 5 72 87 75 53
# totale= 37

# %% [markdown]
# 6\. Combination of functions
#
# Write two functions - one that returns the square of a number, and one that returns the cube. Now write a third function that returns the number raised to the 6th power using the two previous functions.

# %%
def square(x):
    return x*x

def cube(x):
    return x*x*x
   

def sixth(x):
    return square(cube(x))

n=float(input('enter a number:'))
print(sixth(n))
# Out:
# enter a number:2
# 64.0

# %% [markdown]
# 7\. Cubes
#
# Create a list of the cubes of x for x in *[0, 10]* using:
#
# a) a for loop
#
# b) a list comprehension

# %%
cubes = [x**3 for x in range(10)]
print(cubes)
# Out:
# [0, 1, 8, 27, 64, 125, 216, 343, 512, 729]

# %%
l=[]
i=1
for i in range(10):
    l.append(i**3)
    i += 1
print(l)
# Out:
# [0, 1, 8, 27, 64, 125, 216, 343, 512, 729]

# %% [markdown]
# 8\. Nested list comprehension
#
# A Pythagorean triple is an integer solution to the Pythagorean theorem $a^2+b^2=c^2$. The first Pythagorean triple is (3,4,5). Find and put in a tuple all unique Pythagorean triples for the positive integers a, b and c less than 100.

# %%
l = []

for a in range(1, 100):
    for b in range(1, 100):
        for c in range(1, 100):
            if a**2 + b**2 == c**2:
                l.append([a, b, c])

print(l)
# Out:
# [[3, 4, 5], [4, 3, 5], [5, 12, 13], [6, 8, 10], [7, 24, 25], [8, 6, 10], [8, 15, 17], [9, 12, 15], [9, 40, 41], [10, 24, 26], [11, 60, 61], [12, 5, 13], [12, 9, 15], [12, 16, 20], [12, 35, 37], [13, 84, 85], [14, 48, 50], [15, 8, 17], [15, 20, 25], [15, 36, 39], [16, 12, 20], [16, 30, 34], [16, 63, 65], [18, 24, 30], [18, 80, 82], [20, 15, 25], [20, 21, 29], [20, 48, 52], [21, 20, 29], [21, 28, 35], [21, 72, 75], [24, 7, 25], [24, 10, 26], [24, 18, 30], [24, 32, 40], [24, 45, 51], [24, 70, 74], [25, 60, 65], [27, 36, 45], [28, 21, 35], [28, 45, 53], [30, 16, 34], [30, 40, 50], [30, 72, 78], [32, 24, 40], [32, 60, 68], [33, 44, 55], [33, 56, 65], [35, 12, 37], [35, 84, 91], [36, 15, 39], [36, 27, 45], [36, 48, 60], [36, 77, 85], [39, 52, 65], [39, 80, 89], [40, 9, 41], [40, 30, 50], [40, 42, 58], [40, 75, 85], [42, 40, 58], [42, 56, 70], [44, 33, 55], [45, 24, 51], [45, 28, 53], [45, 60, 75], [48, 14, 50], [48, 20, 52], [48, 36, 60], [48, 55, 73], [48, 64, 80], [51, 68, 85], [52, 39, 
# ...

# %% [markdown]
# 9\. Normalization
#
# Write a function that takes a tuple of numbers and returns it with the entries normalized to one

# %%
l=[0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
lsquare = [i**2 for i in l]
print(lsquare)
# Out:
# [0, 1, 16, 81, 256, 625, 1296, 2401, 4096, 6561]

# %%
l=[0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
import numpy as np

def normalization(l):
    l2 = [i**2 for i in l]
    norma = np.sqrt(np.sum(l2))
    L = [x/norma for x in l2]
    return L
print(normalization(l))
# Out:
# [0.0, 0.008075816311961644, 0.1292130609913863, 0.6541411212688931, 2.0674089758621808, 5.047385194976027, 10.46625794030229, 19.390034965019904, 33.07854361379489, 52.985430822780344]

# %%
l=[0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
import numpy as np

def norm(l):
    L=np.array(l, dtype=float)
    q=L**2
    norma=np.sqrt(np.sum(q))
    n=L/norma
    ver=np.sqrt(np.sum(n**2))
    return n, ver

norm(l)
# Out:
# (array([0.        , 0.00807582, 0.03230327, 0.07268235, 0.12921306,
#         0.20189541, 0.29072939, 0.395715  , 0.51685224, 0.65414112]),
#  1.0)
